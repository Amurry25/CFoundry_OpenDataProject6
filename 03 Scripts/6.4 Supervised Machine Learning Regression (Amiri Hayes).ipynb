# %% [markdown]
# # 0.1 Importing

# %%
# importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# This option ensures that the graphs you create are displayed within the notebook without the need to "call" them specifically.
# %matplotlib inline

# %%
# Importing dataframe
path = r'/Users/amirihayes/Desktop/Careery Foundry Files/(1) Data Immersion/Achievement 6/kaggle'

# %%
path
# Out:
# '/Users/amirihayes/Desktop/Careery Foundry Files/(1) Data Immersion/Achievement 6/kaggle'

# %%
# Importing cleaned housing data from 6.2
df_clean = pd.read_csv(os.path.join(path, 'input', 'world-happiness-report', '6.2_world-happiness-report-2015-2019-cleaned.csv'))

# %%
df_clean.head()
# Out:
#    Unnamed: 0  Happiness Rank      Country          Region  Happiness Score  \
# 0           0               1  Switzerland  Western Europe            7.587
# 1           1               2      Iceland  Western Europe            7.561
# 2           2               3      Denmark  Western Europe            7.527
# 3           3               4       Norway  Western Europe            7.522
# 4           4               5       Canada   North America            7.427
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                   1.39651                  1.34951
# 1                   1.30232                  1.40223
# 2                   1.32548                  1.36058
# 3                   1.45900                  1.33095
# 4                   1.32629                  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# ...

# %%
df_clean.shape
# Out:
# (1562, 13)

# %% [markdown]
# # 0.2 Directions 6.4

# %%
# Dropping Column Unnamed: 0
df_clean2 = df_clean.drop(columns=['Unnamed: 0'])

# %%
df_clean2.head()
# Out:
#    Happiness Rank      Country          Region  Happiness Score  \
# 0               1  Switzerland  Western Europe            7.587
# 1               2      Iceland  Western Europe            7.561
# 2               3      Denmark  Western Europe            7.527
# 3               4       Norway  Western Europe            7.522
# 4               5       Canada   North America            7.427
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                   1.39651                  1.34951
# 1                   1.30232                  1.40223
# 2                   1.32548                  1.36058
# 3                   1.45900                  1.33095
# 4                   1.32629                  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df_dups = df_clean2[df_clean2.duplicated()]

# %%
df_dups
# Out:
#       Happiness Rank                   Country              Region  \
# 781                1               Switzerland      Western Europe
# 782                2                   Iceland      Western Europe
# 783                3                   Denmark      Western Europe
# 784                4                    Norway      Western Europe
# 785                5                    Canada       North America
# ...              ...                       ...                 ...
# 1557             152                    Rwanda  Sub-Saharan Africa
# 1558             153                  Tanzania  Sub-Saharan Africa
# 1559             154               Afghanistan       Southern Asia
# 1560             155  Central African Republic  Sub-Saharan Africa
# 1561             156               South Sudan                   -
#
#       Happiness Score  Economy (GDP per Capita)  Family (Social Support)  \
# 781             7.587                   1.39651                  1.34951
# ...

# %%
df_clean2.shape
# Out:
# (1562, 12)

# %%
df_dups.shape
# Out:
# (781, 12)

# %%
df_clean2_no_dups = df_clean2.drop_duplicates()

# %%
df_clean2_no_dups.shape
# Out:
# (781, 12)

# %%
df_clean2_no_dups.head()
# Out:
#    Happiness Rank      Country          Region  Happiness Score  \
# 0               1  Switzerland  Western Europe            7.587
# 1               2      Iceland  Western Europe            7.561
# 2               3      Denmark  Western Europe            7.527
# 3               4       Norway  Western Europe            7.522
# 4               5       Canada   North America            7.427
#
#    Economy (GDP per Capita)  Family (Social Support)  \
# 0                   1.39651                  1.34951
# 1                   1.30232                  1.40223
# 2                   1.32548                  1.36058
# 3                   1.45900                  1.33095
# 4                   1.32629                  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
# Checking for outliers/extreme values in "Happiness Score"
sns.distplot(df_clean2_no_dups['Happiness Score'], bins=25)
# Out:
# /Users/amirihayes/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Happiness Score', ylabel='Density'>

# %%
# Checking for extreme values
sns.distplot(df_clean2_no_dups['Economy (GDP per Capita)'], bins=25)
# Out:
# /Users/amirihayes/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
# Checking for extreme values
sns.distplot(df_clean2_no_dups['Family (Social Support)'], bins=25)
# Out:
# /Users/amirihayes/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Family (Social Support)', ylabel='Density'>

# %%
# Checking for extreme values
sns.distplot(df_clean2_no_dups['Health (Life Expectancy)'], bins=25)
# Out:
# /Users/amirihayes/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
df_clean2_no_dups.plot(x = 'Happiness Score', y='Economy (GDP per Capita)',style='o')
plt.title('Happiness Score vs Economy (GDP per Capita)')  
plt.xlabel('Happiness Score')  
plt.ylabel('Economy (GDP per Capita)')  
plt.show()

# %%
df_clean2_no_dups.plot(x = 'Happiness Score', y='Family (Social Support)',style='o')
plt.title('Happiness Score vs Family (Social Support)')  
plt.xlabel('Happiness Score')  
plt.ylabel('Family (Social Support)')  
plt.show()

# %%
df_clean2_no_dups.plot(x = 'Happiness Score', y='Health (Life Expectancy)',style='o')
plt.title('Happiness Score vs Health (Life Expectancy)')  
plt.xlabel('Happiness Score')  
plt.ylabel('Health (Life Expectancy)')  
plt.show()

# %%
# Reshaping the variables into NumPy arrays and putting them into separate objects.
X = df_clean2_no_dups['Happiness Score'].values.reshape(-1,1)
y = df_clean2_no_dups['Economy (GDP per Capita)'].values.reshape(-1,1)

# %%
X
# Out:
# array([[7.587     ],
#        [7.561     ],
#        [7.527     ],
#        [7.522     ],
#        [7.427     ],
#        [7.406     ],
#        [7.378     ],
#        [7.364     ],
#        [7.286     ],
#        [7.284     ],
#        [7.278     ],
#        [7.226     ],
#        [7.2       ],
#        [7.187     ],
#        [7.119     ],
#        [6.983     ],
#        [6.946     ],
#        [6.94      ],
#        [6.937     ],
#        [6.901     ],
#        [6.867     ],
#        [6.853     ],
#        [6.81      ],
#        [6.798     ],
#        [6.786     ],
#        [6.75      ],
#        [6.67      ],
#        [6.611     ],
#        [6.575     ],
#        [6.574     ],
#        [6.505     ],
#        [6.485     ],
#        [6.477     ],
#        [6.455     ],
#        [6.411     ],
#        [6.329     ],
#        [6.302     ],
#        [6.298     ],
#        [6.295     ],
#        [6.269     ],
#        [6.168     ],
#        [6.13      ],
#        [6.123     ],
# ...

# %%
y
# Out:
# array([[1.39651   ],
#        [1.30232   ],
#        [1.32548   ],
#        [1.459     ],
#        [1.32629   ],
#        [1.29025   ],
#        [1.32944   ],
#        [1.33171   ],
#        [1.25018   ],
#        [1.33358   ],
#        [1.22857   ],
#        [0.95578   ],
#        [1.33723   ],
#        [1.02054   ],
#        [1.39451   ],
#        [0.98124   ],
#        [1.56391   ],
#        [1.33596   ],
#        [1.30782   ],
#        [1.42727   ],
#        [1.26637   ],
#        [1.36011   ],
#        [1.04424   ],
#        [1.52186   ],
#        [1.06353   ],
#        [1.32792   ],
#        [1.10715   ],
#        [1.69042   ],
#        [1.27778   ],
#        [1.05351   ],
#        [1.17898   ],
#        [1.06166   ],
#        [0.91861   ],
#        [0.9669    ],
#        [1.39541   ],
#        [1.23011   ],
#        [1.2074    ],
#        [1.29098   ],
#        [1.55422   ],
#        [0.99534   ],
#        [1.21183   ],
#        [0.76454   ],
#        [0.74553   ],
# ...

# %%
# Splitting the data into a training set and a test set.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %% [markdown]
# # 0.3 Regression Analysis

# %%
# Creating a regression object.
regression = LinearRegression()  # This is the regression object, which will be fit onto the training set.

# %%
# Fit the regression object onto the training set.
regression.fit(X_train, y_train) # training the model
# Out:
# LinearRegression()

# %%
# Predict the values of y using X.
# Using the model on the test data set to predict some y values and see how accurate they are.
y_predicted = regression.predict(X_test)

# %%
# Creating a plot that shows the regression line from the model on the test set.
plot_test = plt
plot_test.scatter(X_test, y_test, color='black', s = 15)
plot_test.plot(X_test, y_predicted, color='red', linewidth =3)
plot_test.title('Happiness Score vs Economy (GDP per Capita) (Test set)')
plot_test.xlabel('Happiness Score')
plot_test.ylabel('Economy (GDP per Capita)')
plot_test.show()

# %%
# Checking the accuracy of the model - mean squared error and R2.
# Creating objects that contain the model summary statistics.
rmse = mean_squared_error(y_test, y_predicted) # This is the mean squared error
r2 = r2_score(y_test, y_predicted) # This is the R2 score.

# %%
# Printing the model's summary statistics. 
print('Slope:' ,regression.coef_)
print('Mean squared error: ', rmse)
print('R2 score: ', r2)
# Out:
# Slope: [[0.28673967]]
# Mean squared error:  0.05843567887241179
# R2 score:  0.6266619231253532

# %% [markdown]
# The **slope coefficient** indicates how the y variable changes when X changes.
#
# The **root mean squared error (MSE)** is an estimator that measures the average of the squared difference between the estimated values and the true values. It states how close a regression line is to a set of points. A small MSE means that the regression line passes fairly close to the observations, making it a good fit. I would interpret the result moderate to high MSE, so **the linear regression line is not a fairly good fit** for this analysis.
#
# The **R2 score** or R squared is a metric that shows how well the model explains the variance in the data. It’s a number between 0 and 1, where values closer to 0 indicate a poor fit, and values closer to 1 indicate a good fit. I would interpret the result as **the fit is weak**.
#
# -----
#
# The **slope** shows that as the Happiness Score (X) rises, Economy (GDP per Capita) appears to steadily rises at a degree of 0.28673967.
#
# The **mean** squared error shows that theres a small average squared difference between estimated and true values thus a regression may an accurate model to predict the relationship between these two variables.
#
# The **R2 score** of 0.626 shows that the model is a pretty good fit.

# %%
# Making a dataframe of y values and their predicted values to further see the performance of the model 
y_predicted
# Out:
# array([[0.94270611],
#        [1.33295877],
#        [1.17754583],
#        [1.39976911],
#        [0.4426321 ],
#        [0.70385191],
#        [0.61725656],
#        [0.80965887],
#        [1.34528857],
#        [0.93209671],
#        [1.21797616],
#        [0.90370948],
#        [0.53610923],
#        [0.82170194],
#        [0.19144815],
#        [1.03159538],
#        [0.55990864],
#        [0.61324218],
#        [0.73481982],
#        [0.91546576],
#        [1.1864348 ],
#        [0.49825959],
#        [0.70614585],
#        [1.13596862],
#        [1.25410536],
#        [0.99804684],
#        [1.00779598],
#        [1.53769089],
#        [0.4070764 ],
#        [1.34356814],
#        [1.18528784],
#        [0.91546581],
#        [1.0310219 ],
#        [0.33625168],
#        [1.43618505],
#        [0.63618137],
#        [0.24248781],
#        [0.82772347],
#        [1.10299359],
#        [1.12707969],
#        [0.6508051 ],
#        [1.06858486],
#        [1.12880012],
# ...

# %%
# Create a dataframe comparing the actual and predicted values of y.
data = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_predicted.flatten()})
data.head(30)
# Out:
#       Actual  Predicted
# 0   1.101803   0.942706
# 1   1.398000   1.332959
# 2   1.530624   1.177546
# 3   1.394510   1.399769
# 4   0.285200   0.442632
# 5   1.156873   0.703852
# 6   0.385000   0.617257
# 7   0.740370   0.809659
# 8   1.425390   1.345289
# 9   1.186490   0.932097
# 10  1.061660   1.217976
# 11  1.164920   0.903709
# 12  0.578000   0.536109
# 13  0.715000   0.821702
# 14  0.015300   0.191448
# 15  1.359480   1.031595
# 16  0.476180   0.559909
# 17  0.900597   0.613242
# 18  1.120940   0.734820
# 19  0.857699   0.915466
# 20  1.824270   1.186435
# 21  0.073000   0.498260
# 22  0.574000   0.706146
# 23  1.362000   1.135969
# 24  1.690420   1.254105
# 25  1.263000   0.998047
# 26  0.751000   1.007796
# 27  1.383000   1.537691
# 28  0.431085   0.407076
# 29  1.356000   1.343568

# %% [markdown]
# Above output compares how the regression fits the training set. This output shows there is some differences between the actual and predicted values.
#
# This is further evidence that the model does in a sense do somewhat explain the relationship between the “Happiness Score' and the 'Economy (GDP per Capita)” variables; not exactly but somewhat.
#
# However, it is really inconsistent the relationship and as a result doesn’t follow a completely straight regression line, perhaps providing further analysis should be indicated to analyze outliers or other variables.

# %%
# Predict.
y_predicted_train = regression.predict(X_train) # This is predicting X_train!

# %%
# Checking the accuracy of the model.
rmse = mean_squared_error(y_train, y_predicted_train)
r2 = r2_score(y_train, y_predicted_train)

# %%
# Printing the model's statistics results. 
print('Slope:' ,regression.coef_)
print('Mean squared error: ', rmse)
print('R2 score: ', r2)
# Out:
# Slope: [[0.28673967]]
# Mean squared error:  0.06351141214234257
# R2 score:  0.6181979086572384

# %%
# Visualizing the training set results.
plot_test = plt
plot_test.scatter(X_train, y_train, color='black', s = 15)
plot_test.plot(X_train, y_predicted_train, color='red', linewidth =3)
plot_test.title('Happiness Score vs Economy (GDP per Capita) (Test set)')
plot_test.xlabel('Happiness Score')
plot_test.ylabel('Economy (GDP per Capita)')
plot_test.show()

# %% [markdown]
# # 0.4 Removing Outliers

# %%
# Cleaning the extreme values from the "Happiness Score" variable observed during the consistency checks.
df_test = df_clean2_no_dups[df_clean2_no_dups['Happiness Score'] <=80]

# %%
# Checking how the scatterplot looks without the outliers.
df_test.plot(x = 'Happiness Score', y='Economy (GDP per Capita)', style='o')  
plt.title('Happiness Score vs Economy (GDP per Capita)')  
plt.xlabel('Happiness Score')
plt.ylabel('Economy (GDP per Capita)')
plt.show()

# %%
# Reshape again.
X_2 = df_test['Happiness Score'].values.reshape(-1,1)
y_2 = df_test['Economy (GDP per Capita)'].values.reshape(-1,1)

# %%
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(X_2, y_2, test_size=0.3, random_state=0)

# %%
# Run and fit the regression.
regression = LinearRegression()  
regression.fit(X_train_2, y_train_2)
# Out:
# LinearRegression()

# %%
# Predict.
y_predicted_2 = regression.predict(X_test_2)

# %%
rmse = mean_squared_error(y_test_2, y_predicted_2)
r2 = r2_score(y_test_2, y_predicted_2)

# %%
print('Slope:' ,regression.coef_)
print('Mean squared error: ', rmse)
print('R2 score: ', r2)
# Out:
# Slope: [[0.28673967]]
# Mean squared error:  0.05843567887241179
# R2 score:  0.6266619231253532

# %%
# Visualizing the test set results.
plot_test = plt
plot_test.scatter(X_test, y_test, color='black', s = 15)
plot_test.plot(X_train, regression.predict(X_train), color='red', linewidth =3)
plot_test.title('Happiness Score vs Economy (GDP per Capita)')
plot_test.xlabel('Happiness Score')
plot_test.ylabel('Economy (GDP per Capita)')
plot_test.show()

# %%
data = pd.DataFrame({'Actual': y_test_2.flatten(), 'Predicted': y_predicted_2.flatten()})

# %%
data.head(30)
# Out:
#       Actual  Predicted
# 0   1.101803   0.942706
# 1   1.398000   1.332959
# 2   1.530624   1.177546
# 3   1.394510   1.399769
# 4   0.285200   0.442632
# 5   1.156873   0.703852
# 6   0.385000   0.617257
# 7   0.740370   0.809659
# 8   1.425390   1.345289
# 9   1.186490   0.932097
# 10  1.061660   1.217976
# 11  1.164920   0.903709
# 12  0.578000   0.536109
# 13  0.715000   0.821702
# 14  0.015300   0.191448
# 15  1.359480   1.031595
# 16  0.476180   0.559909
# 17  0.900597   0.613242
# 18  1.120940   0.734820
# 19  0.857699   0.915466
# 20  1.824270   1.186435
# 21  0.073000   0.498260
# 22  0.574000   0.706146
# 23  1.362000   1.135969
# 24  1.690420   1.254105
# 25  1.263000   0.998047
# 26  0.751000   1.007796
# 27  1.383000   1.537691
# 28  0.431085   0.407076
# 29  1.356000   1.343568

# %% [markdown]
# Again there are some observations with high difference between the actual and predicted values, but there are others with close values. Although the scatterplot shows a good correlation between the variables, the model's statistics results show that the linear regression model doesn't seem to be as good fit as it could be but does for the most part have value.
